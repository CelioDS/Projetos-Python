# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

from keras.src.applications.densenet import preprocess_input
from tensorflow.python.data import AUTOTUNE
from tensorflow.python.keras.utils.version_utils import training


# way for archive of the images
database_photos = 'imagem-treino'

# check if database is true
if os.path.isdir(database_photos):
    print("OK - Database found")
else:
    print("ERROR - Database not found")



# parameter for the load the images
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH  = 224
EPOCHS     = 30 
NAME_MODEL = 'My_models_IA_PHOTO.keras'


# load the training data  ( 80% of the images)
train_dataset = tf.keras.utils.image_dataset_from_directory(
    database_photos,
    validation_split= 0.2,
    subset="training",
    seed=123,
    image_size=(IMG_HEIGHT,IMG_WIDTH),
    batch_size=BATCH_SIZE)

#load the validation data (20% of the images)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    database_photos,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE)


# get the class names
class_names = train_dataset.class_names

AUTOTUNE  = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)

data_augmentation = tf.keras.Sequential({
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
})

preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

base_model = tf.keras.applications.MobileNetV2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
                                               include_top=False,
                                               weights="imagenet")

base_model.trainable = False

inputs = tf.keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.4)(x)

outputs = tf.keras.layers.Dense(1)(x)


model = tf.keras.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS
)


model.save(rf'model\\{NAME_MODEL}')
print(f"\n✅'My model save with success = {NAME_MODEL}") 

# visualizar
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history['loss']
val_loss = history.history["val_loss"]

epochs_range = range(EPOCHS)

plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Acuracia de treino")
plt.plot(epochs_range, val_acc, label="acuracia de validação")
plt.plot(loc='lower right')
plt.title('acuracia de treino e validação')
plt.xlabel('Época')
plt.ylabel('Acurácia')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="perda de treino")
plt.plot(epochs_range, val_loss, label="perda de validaçao")
plt.legend(loc="upper right")
plt.title("perda de treino e validação")
plt.xlabel('Época')
plt.ylabel('Perca')

plt.suptitle('Resultados do Treinamento')
plt.savefig(r'model\\grafico_treino.png')
plt.show()
# Out:
# OK - Database found
# Found 151 files belonging to 2 classes.
# Using 121 files for training.
# Found 151 files belonging to 2 classes.
# Using 30 files for validation.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract_1 (Subtract)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,259,265 (8.62 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.5785 - loss: 0.8617 - val_accuracy: 0.4000 - val_loss: 0.9584
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5785 - loss: 0.8938 - val_accuracy: 0.4333 - val_loss: 0.9020
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5702 - loss: 0.7591 - val_accuracy: 0.4333 - val_loss: 0.8478
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6116 - loss: 0.6970 - val_accuracy: 0.4667 - val_loss: 0.8030
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6281 - loss: 0.6989 - val_accuracy: 0.4667 - val_loss: 0.7609
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6198 - loss: 0.7255 - val_accuracy: 0.4667 - val_loss: 0.7247
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6198 - loss: 0.7152 - val_accuracy: 0.4667 - val_loss: 0.6924
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6860 - loss: 0.6147 - val_accuracy: 0.5667 - val_loss: 0.6644
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6612 - loss: 0.6049 - val_accuracy: 0.5667 - val_loss: 0.6362
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 723ms/step - accuracy: 0.6198 - loss: 0.6599 - val_accuracy: 0.5667 - val_loss: 0.6120
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 727ms/step - accuracy: 0.6694 - loss: 0.6604 - val_accuracy: 0.6000 - val_loss: 0.5936
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 724ms/step - accuracy: 0.7025 - loss: 0.5742 - val_accuracy: 0.6000 - val_loss: 0.5756
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 752ms/step - accuracy: 0.6612 - loss: 0.6515 - val_accuracy: 0.6000 - val_loss: 0.5572
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 831ms/step - accuracy: 0.7273 - loss: 0.5155 - val_accuracy: 0.6000 - val_loss: 0.5407
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 749ms/step - accuracy: 0.7025 - loss: 0.5456 - val_accuracy: 0.6333 - val_loss: 0.5283
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 717ms/step - accuracy: 0.7025 - loss: 0.4925 - val_accuracy: 0.6667 - val_loss: 0.5153
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 719ms/step - accuracy: 0.7025 - loss: 0.5552 - val_accuracy: 0.7000 - val_loss: 0.5041
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 716ms/step - accuracy: 0.6860 - loss: 0.5870 - val_accuracy: 0.7000 - val_loss: 0.4931
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 724ms/step - accuracy: 0.7190 - loss: 0.5336 - val_accuracy: 0.7333 - val_loss: 0.4817
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 716ms/step - accuracy: 0.7190 - loss: 0.5298 - val_accuracy: 0.7667 - val_loss: 0.4716
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 722ms/step - accuracy: 0.7769 - loss: 0.4903 - val_accuracy: 0.7667 - val_loss: 0.4634
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 747ms/step - accuracy: 0.6942 - loss: 0.5616 - val_accuracy: 0.7667 - val_loss: 0.4522
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 768ms/step - accuracy: 0.7273 - loss: 0.5501 - val_accuracy: 0.7667 - val_loss: 0.4424
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 727ms/step - accuracy: 0.7603 - loss: 0.4962 - val_accuracy: 0.7667 - val_loss: 0.4340
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 759ms/step - accuracy: 0.7273 - loss: 0.5407 - val_accuracy: 0.7667 - val_loss: 0.4246
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 727ms/step - accuracy: 0.7355 - loss: 0.4748 - val_accuracy: 0.7667 - val_loss: 0.4166
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 756ms/step - accuracy: 0.7851 - loss: 0.4263 - val_accuracy: 0.7667 - val_loss: 0.4091
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.8017 - loss: 0.4207 - val_accuracy: 0.7667 - val_loss: 0.4014
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 785ms/step - accuracy: 0.6942 - loss: 0.4582 - val_accuracy: 0.7667 - val_loss: 0.3954
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 858ms/step - accuracy: 0.8017 - loss: 0.4230 - val_accuracy: 0.7667 - val_loss: 0.3870
#
# ✅'My model save with success = My_models_IA_PHOTO.keras
